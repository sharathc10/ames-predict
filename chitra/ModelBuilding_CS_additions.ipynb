# %%
import sys
sys.path.append('..')
import CustomPipeline as cp
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

pd.set_option('display.max_rows', 300)

# %%
import CustomPipeline as cp
data = cp.clean('data/trainData.csv')

# %%
data1 = data[['GrLivArea', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt']]

# %%
data = cp.clean('data/trainData.csv')

data['Log_SalePrice'] = np.log(data.SalePrice)
X = data.drop(['PID', 'SalePrice', 'Log_SalePrice'], axis=1, inplace=False)
y = data['Log_SalePrice']

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

alpha_list = np.linspace(0.0001, 0.1, 1000)
results = []

for alpha in alpha_list:
    print(alpha)
    lasso = Lasso(fit_intercept=True, alpha=alpha, max_iter=35000)
    score = cross_val_score(lasso, X, y, cv=3).mean()
    results.append({'alpha':alpha, 'model': lasso, 'score': score})
    
resultsDF = pd.DataFrame(results)
resultsDF = resultsDF.iloc[0:50,]

resultsDF.plot(kind='scatter', x='alpha', y='score')
# Out:
# 0.0001
# /Users/chitrasharathchandra/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.724646970426288, tolerance: 0.023303783977421784
#   model = cd_fast.enet_coordinate_descent(
# /Users/chitrasharathchandra/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.333026446208922, tolerance: 0.02313515262215697
#   model = cd_fast.enet_coordinate_descent(
# /Users/chitrasharathchandra/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.533331879065006, tolerance: 0.024160655566419616
# ...

# %%
sns.lineplot(data=resultsDF, x="alpha", y="score")
# Out:
# <AxesSubplot:xlabel='alpha', ylabel='score'>

# %%
optimal_model = resultsDF['model'][resultsDF['score'] == resultsDF['score'].max()].values[0]

# %%
optimal_model
# Out:
# Lasso(alpha=0.0007000000000000001, max_iter=35000)

# %%
test_data = cp.clean('data/testData.csv')

test_data['Log_SalePrice'] = np.log(test_data.SalePrice)
X_test = test_data.drop(['PID', 'SalePrice', 'Log_SalePrice'], axis=1, inplace=False)
y_test = test_data['Log_SalePrice']

scalar = StandardScaler()
X_test_scaled = scalar.fit_transform(X_test)

# %%
optimal_model.fit(X_scaled, y)
optimal_model.score(X_test_scaled, y_test)
# Out:
# 0.9251346201400765

# %%
for col, coef in zip(X.columns, optimal_model.coef_):
    if abs(coef) > 0:
        print(f'{col}: {coef}')
# Out:
# GrLivArea: 0.12120496128160035
# LotFrontage: 0.0004612261372282641
# LotArea: 0.01616203327696993
# Alley: 0.0016465205364753536
# Utilities: 0.0017857345811758331
# OverallQual: 0.07422048361785295
# OverallCond: 0.05558380406554907
# YearBuilt: 0.07033132434237203
# YearRemodAdd: 0.014359065222362622
# RoofStyle: 0.0019319725005356248
# RoofMatl: 0.002178595688159582
# Exterior1st: 0.011330297428359651
# Exterior2nd: -0.0034307615287992328
# MasVnrArea: 0.0007553991929493178
# ExterQual: 0.013777108889501805
# ExterCond: 0.0003619293878010651
# Foundation: -0.009569820898385704
# BsmtQual: 0.007556618279420956
# BsmtExposure: 0.014680367457363303
# BsmtFinType1: 0.007538699033620996
# BsmtFinSF1: 0.027587551756748294
# BsmtFinSF2: 0.005330885970059297
# TotalBsmtSF: 0.02229020260694631
# 1stFlrSF: 0.016785863944347005
# LowQualFinSF: -0.0039048194845790335
# BsmtFullBath: 0.008301264258736412
# BsmtHalfBath: -0.0008465824444994249
# FullBath: 0.0068654487285065334
# ...

# %%
error = np.exp(optimal_model.predict(X_test_scaled)) - np.exp(y_test)

# %%
error
# Out:
# 0       -2545.980823
# 1        5915.548520
# 2        2840.402952
# 3       -1262.622944
# 4       17381.313157
# 5       16641.175892
# 6       -2399.572647
# 7       -1715.215315
# 8      -12133.421431
# 9       17260.470359
# 10      27759.685969
# 11      35911.936369
# 12      -4392.949274
# 13      -7275.603245
# 14       9252.140188
# 15     -11739.506569
# 16       4007.780537
# 17     -14263.890940
# 18       6725.102809
# 19       3025.571201
# 20    -127130.150928
# 21     -13541.025771
# 22     -17557.860339
# 23     -11115.707094
# 24      18178.434302
# 25     -39365.280068
# 26      12789.845203
# 27      -1874.886494
# 28     -43653.383110
# 29      -1842.785546
# 30      -4110.134210
# 31     -14706.262911
# 32     -20000.954954
# 33      -4205.376187
# 34      21759.893439
# 35      -6185.328417
# 36     -19513.669241
# 37      12419.705432
# 38      11841.883376
# 39       4967.608425
# 40      23538.132417
# 41      -9666.449212
# 42      10514.808874
# ...

# %%
abs(error).min()
# Out:
# 51.67730971885612

# %%
performance = {'predict': np.exp(optimal_model.predict(X_test_scaled)), 'actual':np.exp(y_test)}

# %%
performanceDF = pd.DataFrame(performance)

# %%
# %matplotlib inline
sns.plot(performanceDF)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-098aabe2646d> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 sns.plot(performanceDF)
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
sns.scatterplot(data=performanceDF, x=performanceDF.index, y = performanceDF['predict']-performanceDF['actual'])

# %%
fig = sm.qqplot(performanceDF['predict']-performanceDF['actual'], line='45', fit=True)
plt.show()

# %%
lasso_coef_final = pd.Series(optimal_model.coef_, index=X.columns)
lasso_coef_final=lasso_coef_final[lasso_coef_final>0]
lasso_coef_final.sort_values(ascending=False, inplace=True)
lasso_coef_final.index
# Out:
# Index(['GrLivArea', 'OverallQual', 'YearBuilt', 'OverallCond', 'BsmtFinSF1',
#        'TotalBsmtSF', 'Neighborhood_Crawfor', 'GarageCars',
#        'Neighborhood_Somerst', 'Neighborhood_NridgHt', '1stFlrSF', 'LotArea',
#        'Neighborhood_StoneBr', 'BsmtExposure', 'YearRemodAdd', 'ExterQual',
#        'Functional', 'Exterior1st', 'FireplaceQu', 'ScreenPorch', 'Fireplaces',
#        'GarageCond', 'EnclosedPorch', 'Neighborhood_NoRidge', 'PavedDrive',
#        'GarageArea', 'MSSubClass_70', 'MSSubClass_50', 'BsmtFullBath',
#        'Condition1_Norm', 'MSSubClass_20', 'TotRmsAbvGrd', 'BsmtQual',
#        'BsmtFinType1', 'BldgType_1Fam', 'Neighborhood_ClearCr',
#        'Neighborhood_BrkSide', 'HalfBath', 'FullBath', 'BsmtFinSF2', 'NewHome',
#        'LandContour_HLS', '3SsnPorch', 'Condition1_PosN', 'MSSubClass_75',
#        'WoodDeckSF', 'Neighborhood_Timber', 'GarageFinish', 'Condition2_PosA',
#        'PoolQC', 'MSZoning_RL', 'Neighborhood_IDOTRR', 'RoofMatl',
# ...

# %%
plt.xlabel("Lasso coefficient")
plt.ylabel("Features")
plt.title("Lasso Feature Selection")
lasso_coef_final.head(25).plot.barh(x='index', y='values', rot=0, figsize=(20,20))
plt.savefig("Lasso Feature Selection.png")

# %%
lasso_coef_final.head(25).index
# Out:
# Index(['GrLivArea', 'OverallQual', 'YearBuilt', 'OverallCond', 'BsmtFinSF1',
#        'TotalBsmtSF', 'Neighborhood_Crawfor', 'GarageCars',
#        'Neighborhood_Somerst', 'Neighborhood_NridgHt', '1stFlrSF', 'LotArea',
#        'Neighborhood_StoneBr', 'BsmtExposure', 'YearRemodAdd', 'ExterQual',
#        'Functional', 'Exterior1st', 'FireplaceQu', 'ScreenPorch', 'Fireplaces',
#        'GarageCond', 'EnclosedPorch', 'Neighborhood_NoRidge', 'PavedDrive'],
#       dtype='object')

# %%
#Get predictions needed to use for University Housing work
cleanData=cp.clean('./data/Ames_Housing_Price_Data.csv')
cleanData['Log_SalePrice'] = np.log(cleanData.SalePrice)
XAll = cleanData.drop(['PID', 'SalePrice', 'Log_SalePrice'], axis=1, inplace=False)

scalar = StandardScaler()
XAll_scaled = scalar.fit_transform(XAll)

cleanData['PredSalePrice']=np.exp(optimal_model.predict(XAll_scaled))
cleanData.to_csv("./data/predictedSalePrice.csv")
cleanData

# %%
rf_final_features=set(['OverallQual',
 'GrLivArea',
 'GarageArea',
 'GarageCars',
 'TotalBsmtSF',
 '1stFlrSF',
 'BsmtFinSF1',
 'FullBath',
 'LotArea',
 'YearRemodAdd',
 'YearBuilt',
 'OverallCond',
 'GarageType',
 'GarageYrBlt',
 'BsmtQual',
 'LotFrontage',
 'BsmtUnfSF',
 'BsmtFinType1',
 'OpenPorchSF',
 'MasVnrArea',
 '2ndFlrSF',
 'MSZoning_RM',
 'MoSold',
 'FireplaceQu',
 'MSSubClass_30',
 'WoodDeckSF',
 'Fireplaces',
 'GarageFinish',
 'Exterior1st',
 'ExterCond',
 'ExterQual',
 'Exterior2nd',
 'YrSold',
 'EnclosedPorch',
 'BsmtExposure',
 'BldgType_1Fam',
 'TotRmsAbvGrd',
 'GarageCond',
 'Neighborhood_Crawfor',
 'Foundation',
 'BedroomAbvGr',
 'BsmtFullBath',
 'KitchenAbvGr',
 'PavedDrive',
 'BsmtCond',
 'ScreenPorch',
 'Fence',
 'HalfBath',
 'LotShape',
 'MSSubClass_20',
 'HouseStyle',
 'Neighborhood_OldTown',
 'LandContour_Lvl',
 'Neighborhood_Edwards',
 'MSZoning_RL',
 'RoofStyle',
 'ModernElectrical',
 'MSZoning_C',
 'GarageQual',
 'Condition1_Norm',
 'Functional',
 'BsmtFinSF2',
 'Neighborhood_IDOTRR',
 'LotConfig_Inside',
 'MasVnrType',
 'Alley',
 'BsmtFinType2',
 'LandSlope',
 'Neighborhood_NWAmes',
 'Condition1_Artery',
 'MSSubClass_60',
 'LotConfig_Corner',
 'Neighborhood_NoRidge',
 'NewHome',
 'Neighborhood_NAmes',
 'Neighborhood_Sawyer',
 'Neighborhood_CollgCr',
 'Condition1_RRAe',
 'Condition1_Feedr',
 'LotConfig_CulDSac',
 'LandContour_HLS',
 'MSSubClass_160',
 'Neighborhood_BrkSide',
 'MSSubClass_50',
 'MSSubClass_80',
 'LandContour_Bnk',
 'Neighborhood_Mitchel',
 'Neighborhood_NPkVill',
 'MSZoning_FV',
 'MSSubClass_90',
 'Neighborhood_Somerst',
 'Neighborhood_NridgHt',
 'Neighborhood_SWISU',
 'BsmtHalfBath',
 'MiscVal',
 'Condition1_PosN',
 'LotConfig_FR2',
 'BldgType_Twnhs',
 'MSSubClass_70',
 'BldgType_TwnhsE',
 'Neighborhood_Gilbert',
 'Neighborhood_ClearCr',
 'Neighborhood_StoneBr',
 'MSSubClass_85',
 'Neighborhood_SawyerW',
 'MSZoning_RH',
 'Condition1_RRAn',
 'Neighborhood_Timber',
 'MSSubClass_120',
 'LandContour_Low',
 'MSSubClass_190',
 'LowQualFinSF',
 'MSSubClass_40',
 'Neighborhood_Blmngtn',
 '3SsnPorch',
 'Neighborhood_Veenker',
 'BldgType_2FmCon',
 'Neighborhood_MeadowV',
 'BldgType_Duplex',
 'Neighborhood_BrDale',
 'Condition1_PosA',
 'Condition2_Feedr',
 'MiscFeature',
 'Street_Pave',
 'RoofMatl',
 'GasHeating',
 'MSSubClass_45',
 'PoolArea',
 'MSSubClass_180'])

lasso_final_features= set([
    'GrLivArea', 'OverallQual', 'YearBuilt', 'OverallCond', 'BsmtFinSF1',
       'TotalBsmtSF', 'Neighborhood_Crawfor', 'GarageCars',
       'Neighborhood_Somerst', 'Neighborhood_NridgHt', '1stFlrSF', 'LotArea',
       'Neighborhood_StoneBr', 'BsmtExposure', 'YearRemodAdd', 'ExterQual',
       'Functional', 'Exterior1st', 'FireplaceQu', 'ScreenPorch', 
'Fireplaces',
       'GarageCond', 'EnclosedPorch', 'Neighborhood_NoRidge', 'PavedDrive',
       'GarageArea', 'MSSubClass_70', 'MSSubClass_50', 'BsmtFullBath',
       'Condition1_Norm', 'MSSubClass_20', 'TotRmsAbvGrd', 'BsmtQual',
       'BsmtFinType1', 'BldgType_1Fam', 'Neighborhood_ClearCr',
       'Neighborhood_BrkSide', 'HalfBath', 'FullBath', 'BsmtFinSF2', 'NewHome',
       'LandContour_HLS', '3SsnPorch', 'Condition1_PosN', 'MSSubClass_75',
       'WoodDeckSF', 'Neighborhood_Timber', 'GarageFinish', 'Condition2_PosA',
       'PoolQC', 'MSZoning_RL', 'Neighborhood_IDOTRR', 'RoofMatl',
       'MSSubClass_85', 'Condition1_PosA', 'RoofStyle', 'Neighborhood_Blueste',
       'Utilities', 'Alley', 'GasHeating', 'Street_Grvl', 'LotConfig_CulDSac',
       'GarageQual', 'Neighborhood_Sawyer', 'Condition2_Artery', 'MasVnrArea',
       'ModernElectrical', 'Neighborhood_BrDale', 'LotFrontage', 'ExterCond',
       'Neighborhood_CollgCr', 'GarageType'
])

lasso_top_25=set(['GrLivArea', 'OverallQual', 'YearBuilt', 'OverallCond', 'BsmtFinSF1',
       'TotalBsmtSF', 'Neighborhood_Crawfor', 'GarageCars',
       'Neighborhood_Somerst', 'Neighborhood_NridgHt', '1stFlrSF', 'LotArea',
       'Neighborhood_StoneBr', 'BsmtExposure', 'YearRemodAdd', 'ExterQual',
       'Functional', 'Exterior1st', 'FireplaceQu', 'ScreenPorch', 'Fireplaces',
       'GarageCond', 'EnclosedPorch', 'Neighborhood_NoRidge', 'PavedDrive'    
])
rf_top_25=set([
    'OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars', 'TotalBsmtSF',
       '1stFlrSF', 'BsmtFinSF1', 'FullBath', 'LotArea', 'YearRemodAdd',
       'YearBuilt', 'OverallCond', 'GarageType', 'GarageYrBlt', 'BsmtQual',
       'LotFrontage', 'BsmtUnfSF', 'BsmtFinType1', 'OpenPorchSF', 'MasVnrArea',
       '2ndFlrSF', 'MSZoning_RM', 'MoSold', 'FireplaceQu', 'MSSubClass_30'
])
in_one_and_not_the_other=rf_final_features - lasso_final_features
in_both=rf_final_features.intersection(lasso_final_features)
#print(f"In both:{in_both} ")
in_lasso_not_in_rf=lasso_final_features.difference(rf_final_features)
#print(f'In lasso not in rf:{in_lasso_not_in_rf}')
in_rf_not_in_lasso=rf_final_features.difference(lasso_final_features)
#print(f'In rf not in lasso:{in_rf_not_in_lasso}')
# Out:
# In both top 25:{'TotalBsmtSF', 'FireplaceQu', 'GrLivArea', 'OverallCond', '1stFlrSF', 'GarageCars', 'YearRemodAdd', 'YearBuilt', 'BsmtFinSF1', 'OverallQual', 'LotArea'}
# In lasso top 25 not in rf top 25:{'Neighborhood_Somerst', 'Neighborhood_NoRidge', 'Exterior1st', 'Neighborhood_Crawfor', 'ScreenPorch', 'Fireplaces', 'GarageCond', 'BsmtExposure', 'PavedDrive', 'ExterQual', 'EnclosedPorch', 'Neighborhood_NridgHt', 'Neighborhood_StoneBr', 'Functional'}
# In rf top 25 not in lasso top 25:{'BsmtQual', 'GarageYrBlt', 'GarageArea', '2ndFlrSF', 'BsmtUnfSF', 'MSZoning_RM', 'FullBath', 'LotFrontage', 'GarageType', 'BsmtFinType1', 'MasVnrArea', 'MoSold', 'MSSubClass_30', 'OpenPorchSF'}
# ...

# %%
#Analyze top 25
print(f'In both top 25:{rf_top_25-lasso_top_25}\n')
top_25_in_lasso_not_in_rf=lasso_top_25.difference(rf_top_25)
print(f'In lasso top 25 not in rf top 25:{top_25_in_lasso_not_in_rf}\n')
print(f'In rf top 25 not in lasso top 25:{top_25_in_rf_not_in_lasso}\n')
print(f'Top 25 - in one and not the other {rf_top_25 ^ lasso_top_25}\n')
print(f'Top 25 - are all in rf top 25 that are not in lasso top 25 in lasso final list: {top_25_in_lasso_not_in_rf.issubset(lasso_top_25)}\n')
print(f'Top 25 - are all in lasso top 25 that are not in rf top 25 in rf final list: {top_25_in_rf_not_in_lasso.issubset(rf_top_25)}\n')
# Out:
# In both top 25:{'BsmtQual', 'GarageYrBlt', 'GarageArea', '2ndFlrSF', 'BsmtUnfSF', 'MSZoning_RM', 'FullBath', 'LotFrontage', 'GarageType', 'BsmtFinType1', 'MasVnrArea', 'MoSold', 'MSSubClass_30', 'OpenPorchSF'}
#
# In lasso top 25 not in rf top 25:{'Neighborhood_Somerst', 'Neighborhood_NoRidge', 'Exterior1st', 'Neighborhood_Crawfor', 'ScreenPorch', 'Fireplaces', 'GarageCond', 'BsmtExposure', 'PavedDrive', 'ExterQual', 'EnclosedPorch', 'Neighborhood_NridgHt', 'Neighborhood_StoneBr', 'Functional'}
#
# In rf top 25 not in lasso top 25:{'BsmtQual', 'GarageYrBlt', 'GarageArea', '2ndFlrSF', 'BsmtUnfSF', 'MSZoning_RM', 'FullBath', 'LotFrontage', 'GarageType', 'BsmtFinType1', 'MasVnrArea', 'MoSold', 'MSSubClass_30', 'OpenPorchSF'}
#
# ...
